# %%
from PIL import Image
img = Image.open('dog.jpg') #metodo RELATIVO
# img = Image.open('C:/Users/ifoa/Downloads/dog.jpg') metodo ASSOLUTO, da evitare 
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1365>
